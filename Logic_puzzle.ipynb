# %%
import sys
sys.path.append("/content/aima-python")
from itertools import combinations
from  logic import *
from utils import *

# %%
def solve_potter_puzzle():

  people = ['Mummy', 'Daddy', 'Peter', 'Betty', 'Polly']
  desserts = ['IceCream', 'Marmalade', 'Marshmallows', 'Napoleon', 'Waffles']
  dreams = ['Paris', 'Sea', 'SwanLake', 'Coins']
  clauses = []
#create propositional symbols
  def Likes(person, dessert): return expr(f'Likes_{person}_{dessert}')
  def Dreams(person, dream): return expr(f'Dream_{person}_{dream}')

# Each person likes exactly one thing at least one + at most one
  for p in people:

        clauses.append(associate('|', [Likes(p, d) for d in desserts]))

        for i in range(len(desserts)):
            for j in range(i + 1, len(desserts)):
                clauses.append(~Likes(p, desserts[i]) | ~Likes(p, desserts[j]))

    # Each person has exactly one dream
  for p in people:
    clauses.append(associate('|', [Dreams(p, d) for d in dreams]))

    for i in range(len(dreams)):
        for j in range(i + 1, len(dreams)):
            clauses.append(~Dreams(p, dreams[i]) | ~Dreams(p, dreams[j]))


  # Each dessert is liked by only one person
  for d in desserts:
    clauses.append(associate('|', [Likes(p, d) for p in people]))
    for i in range(len(people)):
        for j in range(i + 1, len(people)):
            clauses.append(~Likes(people[i], d) | ~Likes(people[j], d))

#C2
  for p in people:
          clauses.append(~Likes(p, 'IceCream') |  Dreams(p, 'Paris'))
  #C3
  clauses.append(Likes('Betty', 'Marmalade'))
  #C4
  clauses.append(Likes('Mummy', 'Marshmallows'))
  #C5
  family = ['Mummy', 'Daddy', 'Peter', 'Betty']
  for p in family:
      clauses.append(~Dreams(p, 'Paris'))

  #Every family memeber and their dream
  clauses.append(associate('|', [Dreams(p, 'Sea') for p in family]))
  clauses.append(associate('|', [Dreams(p, 'SwanLake') for p in family]))
  clauses.append(associate('|', [Dreams(p, 'Coins') for p in family]))
  #C6
  clauses.append(Dreams('Betty', 'SwanLake'))

  #C7
  clauses.append(Dreams('Peter', 'Coins'))

  #C8
  clauses.append(~Likes('Peter', 'Napoleon'))
  clauses.append(~Likes('Peter', 'IceCream'))

  #C9
  for d in dreams:
    clauses.append(~Dreams('Mummy',d) | Dreams('Daddy',d))
    clauses.append(~Dreams('Daddy',d) | Dreams('Mummy',d))



  #C10
  clauses.append(associate('|', [Likes(p, 'Napoleon') for p in family]))
  clauses.append(associate('|', [Likes(p, 'Waffles') for p in family]))

  full_clause=associate('&', clauses)
  solution=dpll_satisfiable(full_clause)

  # print(solution)

  napoleon_lover = []
  paris_dreamer = []

  for p in people:
    if solution[Likes(p, 'Napoleon')]:
      napoleon_lover.append(p)
    if solution[Dreams(p, 'Paris')]:
      paris_dreamer.append(p)

  print(f"People who like Napoleon: {napoleon_lover}")
  print(f"People who dream of Paris: {paris_dreamer}")

# %% [markdown]
# # **OUTPUT**

# %%
solve_potter_puzzle()
# Out:
# {Likes_Betty_Marmalade: True, Likes_Betty_IceCream: False, Likes_Betty_Marshmallows: False, Likes_Betty_Napoleon: False, Likes_Betty_Waffles: False, Likes_Mummy_Marmalade: False, Likes_Daddy_Marmalade: False, Likes_Peter_Marmalade: False, Likes_Polly_Marmalade: False, Likes_Mummy_Marshmallows: True, Likes_Mummy_IceCream: False, Likes_Mummy_Napoleon: False, Likes_Mummy_Waffles: False, Likes_Daddy_Marshmallows: False, Likes_Peter_Marshmallows: False, Likes_Polly_Marshmallows: False, Dream_Mummy_Paris: False, Dream_Daddy_Paris: False, Likes_Daddy_IceCream: False, Dream_Peter_Paris: False, Likes_Peter_IceCream: False, Likes_Polly_IceCream: True, Likes_Polly_Napoleon: False, Likes_Polly_Waffles: False, Dream_Polly_Paris: True, Dream_Polly_SwanLake: False, Dream_Polly_Sea: False, Dream_Polly_Coins: False, Dream_Betty_Paris: False, Dream_Betty_SwanLake: True, Dream_Betty_Sea: False, Dream_Betty_Coins: False, Dream_Peter_Coins: True, Dream_Peter_SwanLake: False, Dream_Peter_Sea: False, Likes_Peter_Napoleon: False, Likes_Peter_Waffles: True, Likes_Daddy_Napoleon: True, Likes_Daddy_Waffles: False, Dream_Daddy_SwanLake: False, Dream_Mummy_SwanLake: False, Dream_Daddy_Coins: False, Dream_Daddy_Sea: True, Dream_Mummy_Sea: True, Dream_Mummy_Coins: False}
# People who like Napoleon: ['Daddy']
# People who dream of Paris: ['Polly']
